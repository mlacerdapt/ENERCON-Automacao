# %%
import pandas as pd

tabela = pd.read_excel(r"O:\02-Blades\14-Cutting\5 -Ordens_entregas_erros\E103 Corte e Pré Corte.xlsx","Casca LS_LP E103")
display(tabela)
# Out:
#     Unnamed: 0           Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 0   Corte E103                  NaN         NaN        NaN
# 1         SAPS                  NaN         NaN        NaN
# 2          SAP                 Nome         NaN        NaN
# 3       623070           Casca LS           NaN          €
# 4       623069             Casca LP         NaN          €
# 5       652873              Colagem         NaN          €
# 6       642015            Alma BA 1         NaN          €
# 7       642016            Alma BA 2         NaN          €
# 8       642017            Alma BA 3         NaN          €
# 9       640369            Alma BF 1         NaN          €
# 10      640370            Alma BF 2         NaN          €
# 11      640371            Alma BF 3         NaN          €
# 12      636736   Bordo Fuga Spoiler         NaN          €
# 13      636741         Alma Spoiler         NaN          €
# 14      636729           Spoiler LS         NaN          €
# ...
